# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904208/baitap/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall , kit , liv, bed ,bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "living room", liv, bed, "bathroom",bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv]]
print(house)
print(type(house))
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]
# [11.25, 18.0, 'living room', 20.0, 10.75, 'bathroom', 9.5]
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
x = ["a", "b", "c"]
y = x + ["d"]
y[1] = "r"
print(y)
# Out:
# 11.25
# 9.5
# 20.0
# 28.75
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]
# ['a', 'r', 'c', 'd']

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathoom", 9.50]
areas[1] = 10.50
areas[4] = "chill zone"
print(areas)
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]
areas_1 = areas + ["poolhouse", 24.5]
areas_2 = list(areas_1)
areas_2.extend(["garage", 15.45])
print(areas_1)
print(areas_2)
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]
del(areas[-4])
del(areas[-3])
print(areas)
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
areas_copy = list(areas)
areas_copy[0] = 5.0
print(areas)
# Out:
# ['hallway', 10.5, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathoom', 9.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5, 'garage', 15.45]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'garage', 15.45]
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
var1 = [1, 2, 3, 4]
var2 = True
print(type(var1))
print(type(var2))
out2 = int(var2)
help(complex)
help(sorted)
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]
full = first + second
full_sorted = sorted(full, reverse=True)
print(full_sorted)
# Out:
# <class 'list'>
# <class 'bool'>
# Help on class complex in module builtins:
#
# class complex(object)
#  |  complex(real=0, imag=0)
#  |
#  |  Create a complex number from a string or numbers.
#  |
#  |  If a string is given, parse it as a complex number.
#  |  If a single number is given, convert it to a complex number.
#  |  If the 'real' or 'imag' arguments are given, create a complex number
#  |  with the specified real and imaginary components.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __complex__(self, /)
#  |      Convert this value to exact type complex.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Convert to a string according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
room = "poolhouse"
room_up = room.upper()
print(room, room_up)
print(len(room))
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
print(areas.index(20))
print(areas.count(14.5))
areas.append(24.5)
areas.append(15.45)
print(areas)
areas.reverse()
print(areas)
# Out:
# poolhouse POOLHOUSE
# 9
# 2
# 0
# [11.25, 18.0, 20.0, 10.75, 9.5, 24.5, 15.45]
# [15.45, 24.5, 9.5, 10.75, 20.0, 18.0, 11.25]

# %%
import numpy

arr = numpy.array([1, 2, 3])

print(arr)
import numpy as np

arr = np.array([1, 2, 3])

print(arr)
r = 0.43

import math

C = 2 * math.pi * r

S = math.pi * r **2

print("Chu vi: " + str(C))
print("Diện tích: " + str(S))
r = 192500

from  math import radians

dist = radians(12) * r

print(dist)
# Out:
# [1 2 3]
# [1 2 3]
# Chu vi: 2.701769682087222
# Diện tích: 0.5808804816487527
# 40317.10572106901

# %%
n = int(input("Nhập n: "))
tong_chan = 0
tong_le = 0

for i in range(n):
    x = int(input("Nhập phần tử: "))
    if x % 2 == 0:
        tong_chan += x
    else:
        tong_le += x

print("Tổng chẵn =", tong_chan)
print("Tổng lẻ =", tong_le)
# Out:
# Nhập n: 5
# Nhập phần tử: 1
# Nhập phần tử: 2
# Nhập phần tử: 3
# Nhập phần tử: 4
# Nhập phần tử: 5
# Tổng chẵn = 6
# Tổng lẻ = 9
